# %%
car=["BMW", "Maruti", "Audi", "Benz","Hyundai"]
country=["USA","India","UK", "Saudi","China"]
price=["200","34","198","150","40"]
car_dict={"Car":car,"country":country,"price":price}
import pandas as pd
a=pd.DataFrame(car_dict, columns=[country,car])
a
# Out:
# Empty DataFrame
# Columns: [(USA, BMW), (India, Maruti), (UK, Audi), (Saudi, Benz), (China, Hyundai)]
# Index: []

# %%
a=pd.Series(car_dict,dtype=str)
a
# Out:
# Car        (BMW, Maruti, Audi, Benz, Hyundai)
# country        (USA, India, UK, Saudi, China)
# price                 (200, 34, 198, 150, 40)
# dtype: object

# %%
n=pd.read_csv("cars.csv",sep=",",header=None)
n
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
df = pd.read_csv(r'https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv', sep="|",header=None)# Write your answer here
df
# Out:
#      0        1            2   3   4   5
# 0    1   Akshay  Mathematics  50  40  80
# 1    2   Mahima      English  40  33  83
# 2    3    Vikas  Mathematics  50  42  84
# 3    4  Abhinav      English  40  31  78
# 4    5   Mahima      Science  50  40  80
# 5    6   Akshay      Science  50  49  98
# 6    7  Abhinav  Mathematics  50  47  94
# 7    8    Vikas      Science  50  40  80
# 8    9  Abhinav      Science  50  47  94
# 9   10    Vikas      English  40  39  98
# 10  11   Akshay      English  40  35  88
# 11  12   Mahima  Mathematics  50  43  86

# %%
df[df/df.5]
# Out:
#   File "<ipython-input-8-4d8fcbd1e9b0>", line 1
#     df[df/df.5]
#              ^
# SyntaxError: invalid syntax

# %%
n=pd.read_csv("cars.csv",header=None, index_col=1)
n
# Out:
#          0              2      3      4
# 1
# US    USCA  United States  809.0  False
# AUS  ASPAC      Australia  731.0   True
# JAP  ASPAC          Japan  588.0   True
# IN   ASPAC          India   18.0   True
# RU   ASPAC         Russia  200.0  False
# MOR  LATAM        Morocco   70.0  False
# EG     AFR          Egypt   45.0  False
# ENG    EUR        England    NaN   True

# %%
n.index.name
# Out:
# 1

# %%
n.columns
# Out:
# Int64Index([0, 2, 3, 4], dtype='int64')

# %%
n.columns=["region","country","price","drive_right"]

# %%
n.index.name = "S.N"

# %%
n=pd.read_csv("cars.csv",header=None, index_col=[0,1])
n.index.names=["Region", "Country"]
n.columns=["City","Price","Drive_right"]
n
# Out:
#                          City  Price  Drive_right
# Region Country
# USCA   US       United States  809.0        False
# ASPAC  AUS          Australia  731.0         True
#        JAP              Japan  588.0         True
#        IN               India   18.0         True
#        RU              Russia  200.0        False
# LATAM  MOR            Morocco   70.0        False
# AFR    EG               Egypt   45.0        False
# EUR    ENG            England    NaN         True

# %%
import pandas as pd
n=int(input())
d={}
for i in range (1, n+1):
    d[i]=i*i

a=pd.Series(d)
a
# Out:
# 5
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# dtype: int64

# %%
n=pd.read_csv("marks_1.csv", sep="|",header=None,index_col=0)
n.index.name="S.No."
n.columns=["Name", "Subject","Maximum Marks", "Marks Obtained","Percentage"]
n
# Out:
#           Name      Subject  Maximum Marks  Marks Obtained  Percentage
# S.No.
# 1       Akshay  Mathematics             50              40          80
# 2       Mahima      English             40              33          83
# 3        Vikas  Mathematics             50              42          84
# 4      Abhinav      English             40              31          78
# 5       Mahima      Science             50              40          80
# 6       Akshay      Science             50              49          98
# 7      Abhinav  Mathematics             50              47          94
# 8        Vikas      Science             50              40          80
# 9      Abhinav      Science             50              47          94
# 10       Vikas      English             40              39          98
# 11      Akshay      English             40              35          88
# 12      Mahima  Mathematics             50              43          86

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6c4bab4f8076> in <module>
# ----> 1 n.groupby(["Name","Subject"])/n.Percentage
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     498         lvalues = extract_array(left, extract_numpy=True)
#     499         rvalues = extract_array(right, extract_numpy=True)
# --> 500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
#     502         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
# ...

# %%
n=pd.read_excel("sales.xlsx", index_col=0)
n.head(9)
# Out:
#                          Region  No_of_Orders    Profit      Sales
# Market
# Africa           Western Africa           251 -12901.51   78476.06
# Africa          Southern Africa            85  11768.58   51319.50
# Africa             North Africa           182  21643.08   86698.89
# Africa           Eastern Africa           110   8013.04   44182.60
# Africa           Central Africa           103  15606.30   61689.99
# Asia Pacific       Western Asia           382 -16766.90  124312.24
# Asia Pacific      Southern Asia           469  67998.76  351806.60
# Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# Asia Pacific            Oceania           646  54734.02  408002.98

# %%
n.tail(5)
# Out:
#              Region  No_of_Orders    Profit      Sales
# Market
# USCA     Western US           490  44303.65  251991.83
# USCA    Southern US           255  19991.83  148771.91
# USCA     Eastern US           443  47462.04  264973.98
# USCA     Central US           356  33697.43  170416.31
# USCA         Canada            49   7246.62   26298.81

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, Africa to USCA
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Region        23 non-null     object
#  1   No_of_Orders  23 non-null     int64
#  2   Profit        23 non-null     float64
#  3   Sales         23 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 920.0+ bytes

# %%
n.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
n.shape
# Out:
# (23, 4)

# %%
n[11:15]
# Out:
#                  Region  No_of_Orders    Profit      Sales
# Market
# Europe   Western Europe           964  82091.27  656637.14
# Europe  Southern Europe           338  18911.49  215703.93
# Europe  Northern Europe           367  43237.44  252969.09
# Europe   Eastern Europe           241  25050.69  108258.93

# %%
n[["Profit","Sales"]].head()
# Out:
#           Profit     Sales
# Market
# Africa -12901.51  78476.06
# Africa  11768.58  51319.50
# Africa  21643.08  86698.89
# Africa   8013.04  44182.60
# Africa  15606.30  61689.99

# %%
type(n[["Profit","Sales"]])
# Out:
# pandas.core.frame.DataFrame

# %%
n=pd.read_excel("sales.xlsx", index_col=0)
n[["Profit","Sales"]].head()
type(n["Profit"])
# Out:
# pandas.core.series.Series

# %%
n[2::2].head(20)
# Out:
#                        Region  No_of_Orders    Profit      Sales
# Market
# Africa           North Africa           182  21643.08   86698.89
# Africa         Central Africa           103  15606.30   61689.99
# Asia Pacific    Southern Asia           469  67998.76  351806.60
# Asia Pacific          Oceania           646  54734.02  408002.98
# Asia Pacific     Central Asia            37  -2649.76    8190.74
# Europe        Southern Europe           338  18911.49  215703.93
# Europe         Eastern Europe           241  25050.69  108258.93
# LATAM         Central America           930  74679.54  461670.28
# USCA               Western US           490  44303.65  251991.83
# USCA               Eastern US           443  47462.04  264973.98
# USCA                   Canada            49   7246.62   26298.81

# %%
n.loc[["USCA","Europe"],["Profit", "Sales"]]
# Out:
#           Profit      Sales
# Market
# USCA    44303.65  251991.83
# USCA    19991.83  148771.91
# USCA    47462.04  264973.98
# USCA    33697.43  170416.31
# USCA     7246.62   26298.81
# Europe  82091.27  656637.14
# Europe  18911.49  215703.93
# Europe  43237.44  252969.09
# Europe  25050.69  108258.93

# %%
n.iloc[0:5,2:]
# Out:
#           Profit     Sales
# Market
# Africa -12901.51  78476.06
# Africa  11768.58  51319.50
# Africa  21643.08  86698.89
# Africa   8013.04  44182.60
# Africa  15606.30  61689.99

# %%
n.iloc[[1,2,3,4],[2,3]]
# Out:
#           Profit     Sales
# Market
# Africa  11768.58  51319.50
# Africa  21643.08  86698.89
# Africa   8013.04  44182.60
# Africa  15606.30  61689.99

# %%
n[n["Profit"]>0]
# Out:
#                          Region  No_of_Orders    Profit      Sales
# Market
# Africa          Southern Africa            85  11768.58   51319.50
# Africa             North Africa           182  21643.08   86698.89
# Africa           Eastern Africa           110   8013.04   44182.60
# Africa           Central Africa           103  15606.30   61689.99
# Asia Pacific      Southern Asia           469  67998.76  351806.60
# Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# Asia Pacific            Oceania           646  54734.02  408002.98
# Asia Pacific       Eastern Asia           414  72805.10  315390.77
# Europe           Western Europe           964  82091.27  656637.14
# Europe          Southern Europe           338  18911.49  215703.93
# Europe          Northern Europe           367  43237.44  252969.09
# Europe           Eastern Europe           241  25050.69  108258.93
# LATAM             South America           496  12377.59  210710.49
# ...

# %%
n[n["Profit"]>0].count()
# Out:
# Region          20
# No_of_Orders    20
# Profit          20
# Sales           20
# dtype: int64

# %%
n.Sales=n.Sales.floordiv(1000)
n
# Out:
#                          Region  No_of_Orders    Profit  Sales
# Market
# Africa           Western Africa           251 -12901.51   78.0
# Africa          Southern Africa            85  11768.58   51.0
# Africa             North Africa           182  21643.08   86.0
# Africa           Eastern Africa           110   8013.04   44.0
# Africa           Central Africa           103  15606.30   61.0
# Asia Pacific       Western Asia           382 -16766.90  124.0
# Asia Pacific      Southern Asia           469  67998.76  351.0
# Asia Pacific  Southeastern Asia           533  20948.84  329.0
# Asia Pacific            Oceania           646  54734.02  408.0
# Asia Pacific       Eastern Asia           414  72805.10  315.0
# Asia Pacific       Central Asia            37  -2649.76    8.0
# Europe           Western Europe           964  82091.27  656.0
# Europe          Southern Europe           338  18911.49  215.0
# Europe          Northern Europe           367  43237.44  252.0
# ...

# %%
n.rename(columns={"Sales":"Sales in thousend"},inplace=True)
n
# Out:
#                          Region  No_of_Orders    Profit  Sales in thousend
# Market
# Africa           Western Africa           251 -12901.51               78.0
# Africa          Southern Africa            85  11768.58               51.0
# Africa             North Africa           182  21643.08               86.0
# Africa           Eastern Africa           110   8013.04               44.0
# Africa           Central Africa           103  15606.30               61.0
# Asia Pacific       Western Asia           382 -16766.90              124.0
# Asia Pacific      Southern Asia           469  67998.76              351.0
# Asia Pacific  Southeastern Asia           533  20948.84              329.0
# Asia Pacific            Oceania           646  54734.02              408.0
# Asia Pacific       Eastern Asia           414  72805.10              315.0
# Asia Pacific       Central Asia            37  -2649.76                8.0
# ...

# %%
n["profit in %"]=n.Profit.apply(lambda x:x%100 if x>0)
# Out:
#   File "<ipython-input-150-b7a5f0cdab96>", line 1
#     n["profit in %"]=n.Profit.apply(lambda x:x%100 if x>0)
#                                                          ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
df["Traning"]=df.Rating.apply(lambda x:"Yes" if x<=3.5 else "No")
df.head()
# Out:
#       ID Department     Office  Rating Traning
# 0  U2F26    Finance  New Delhi     3.4     Yes
# 1  U2M61  Marketing  New Delhi     3.9      No
# 2  U1S15      Sales  New Delhi     2.8     Yes
# 3  U1H87         HR     Mumbai     2.1     Yes
# 4  U1S51      Sales  New Delhi     4.6      No

# %%
n.reset_index(inplace=True)
n.set_index(["Market","Region"],inplace=True)
n
# Out:
#                                 No_of_Orders    Profit  Sales in thousend
# Market       Region
# Africa       Western Africa              251 -12901.51               78.0
#              Southern Africa              85  11768.58               51.0
#              North Africa                182  21643.08               86.0
#              Eastern Africa              110   8013.04               44.0
#              Central Africa              103  15606.30               61.0
# Asia Pacific Western Asia                382 -16766.90              124.0
#              Southern Asia               469  67998.76              351.0
#              Southeastern Asia           533  20948.84              329.0
#              Oceania                     646  54734.02              408.0
#              Eastern Asia                414  72805.10              315.0
#              Central Asia                 37  -2649.76                8.0
# ...

# %%
n[["No_of_Orders"]].groupby("Market").sum()
# Out:
#               No_of_Orders
# Market
# Africa                 731
# Asia Pacific          2481
# Europe                1910
# LATAM                 1714
# USCA                  1593

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF',index_col=[2,3])
#Type your groupby command here
df_1 = df[["rain","wind"]].groupby(["month","day"]).mean()#Type your code to find the mean of columns 'rain' and 'wind'
print(df_1.head(20))
# Out:
#                rain      wind
# month day
# apr   fri  0.000000  3.100000
#       mon  0.000000  3.100000
#       sat  0.000000  4.500000
#       sun  0.000000  5.666667
#       thu  0.000000  5.800000
#       wed  0.000000  2.700000
# aug   fri  0.066667  4.766667
#       mon  0.000000  2.873333
#       sat  0.000000  4.310345
#       sun  0.025000  4.417500
#       thu  0.000000  3.503846
#       tue  0.300000  4.567857
#       wed  0.000000  3.520000
# dec   fri  0.000000  4.900000
#       mon  0.000000  8.500000
#       sun  0.000000  8.500000
#       thu  0.000000  4.900000
#       tue  0.000000  8.500000
#       wed  0.000000  8.000000
# feb   fri  0.000000  4.820000

# %%
import matplotlib.pyplot as plt
import pandas as pd
users= pd.DataFrame({"weekday" : ['Sun', 'Sun', 'Mon', 'Mon'],
                    "city": ['Austin', 'Dallas', 'Austin', 'Dallas'],
                    "visitors":[139, 237, 326, 456],
                    "signups" : [7, 12, 3, 5]})
users.set_index("weekday",inplace=True)
users.plot(kind="bar")
plt.show()

# %%
visitor=users.pivot(columns="city",values="visitors")
visitor
# Out:
# city     Austin  Dallas
# weekday
# Mon         326     456
# Sun         139     237

# %%
visitor.plot(kind='bar')
plt.show()

# %%
visitor=users.pivot(columns="city")
visitor.plot(kind="bar")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://query.data.world/s/vBDCsoHCytUSLKkLvq851k2b8JOCkF')
df.set_index(["month","day"],inplace=True)
df_1=df.pivot_table(index=["month","day"], values=["rain","wind"], aggfunc="mean")
df_1
# Out:
#            rain      wind
# month day
# apr   fri   0.0  3.100000
#       mon   0.0  3.100000
#       sat   0.0  4.500000
#       sun   0.0  5.666667
#       thu   0.0  5.800000
# ...         ...       ...
# sep   sat   0.0  3.460000
#       sun   0.0  3.955556
#       thu   0.0  3.357143
#       tue   0.0  3.431579
#       wed   0.0  3.378571
#
# [64 rows x 2 columns]

# %%
import pandas as pd
nr=pd.read_excel("sales_returns.xlsx", sheet_name="Returns")
n=pd.read_excel("sales_returns.xlsx", sheet_name="Orders")
n.head()
# Out:
#                Order ID  Market  Profit   Sales
# 0  AG-2012-AA6453-41020  Africa   53.76  298.68
# 1  AG-2012-AC4203-40915  Africa   14.58   91.38
# 2  AG-2012-AH2103-41133  Africa   11.04  276.96
# 3  AG-2012-AJ7803-40978  Africa    7.17   35.97
# 4  AG-2012-AS2853-41235  Africa   15.36   54.90

# %%
n.merge(nr, on=["Order ID"])
# Out:
#                       Order ID  Market    Profit     Sales Returned
# 0        AG-2013-PO88653-41634  Africa  191.2500  1932.240      Yes
# 1        AG-2014-CM21603-41755  Africa   10.3200    43.050      Yes
# 2        AG-2014-CP20853-41889  Africa   14.1000    84.720      Yes
# 3        AG-2014-RD95853-41712  Africa   21.0300    64.380      Yes
# 4        AO-2013-JE57454-41544  Africa  106.5900   499.230      Yes
# ...                        ...     ...       ...       ...      ...
# 1074  US-2015-ME17320140-42322    USCA  -24.7086     9.324      Yes
# 1075  US-2015-PN18775140-42339    USCA    8.9970    71.976      Yes
# 1076  US-2015-RL19615140-42147    USCA   18.8328    49.560      Yes
# 1077  US-2015-SC20050140-42278    USCA  -17.4690    11.646      Yes
# 1078  US-2015-TT21220140-42186    USCA  100.4255   204.950      Yes
#
# [1079 rows x 5 columns]

# %%
nr_ord=n.merge(nr, on=["Order ID"], how="left")
nr_ord
# Out:
#                        Order ID  Market   Profit    Sales Returned
# 0          AG-2012-AA6453-41020  Africa  53.7600  298.680      NaN
# 1          AG-2012-AC4203-40915  Africa  14.5800   91.380      NaN
# 2          AG-2012-AH2103-41133  Africa  11.0400  276.960      NaN
# 3          AG-2012-AJ7803-40978  Africa   7.1700   35.970      NaN
# 4          AG-2012-AS2853-41235  Africa  15.3600   54.900      NaN
# ...                         ...     ...      ...      ...      ...
# 25723  US-2015-VM21835140-42252    USCA   6.9654   14.820      NaN
# 25724  US-2015-WB21850140-42349    USCA  12.8767   91.193      NaN
# 25725  US-2015-XP21865140-42287    USCA  16.5440   35.200      NaN
# 25726  US-2015-XP21865140-42323    USCA -22.7882  212.992      NaN
# 25727  US-2015-ZC21910140-42175    USCA  41.1900  148.884      NaN
#
# [25728 rows x 5 columns]

# %%
nr_ord["Returned"]=nr_ord["Returned"].astype('str')
nr_ord
# Out:
#                        Order ID  Market   Profit    Sales Returned
# 0          AG-2012-AA6453-41020  Africa  53.7600  298.680      nan
# 1          AG-2012-AC4203-40915  Africa  14.5800   91.380      nan
# 2          AG-2012-AH2103-41133  Africa  11.0400  276.960      nan
# 3          AG-2012-AJ7803-40978  Africa   7.1700   35.970      nan
# 4          AG-2012-AS2853-41235  Africa  15.3600   54.900      nan
# ...                         ...     ...      ...      ...      ...
# 25723  US-2015-VM21835140-42252    USCA   6.9654   14.820      nan
# 25724  US-2015-WB21850140-42349    USCA  12.8767   91.193      nan
# 25725  US-2015-XP21865140-42287    USCA  16.5440   35.200      nan
# 25726  US-2015-XP21865140-42323    USCA -22.7882  212.992      nan
# 25727  US-2015-ZC21910140-42175    USCA  41.1900  148.884      nan
#
# [25728 rows x 5 columns]

# %%
nr_ord["Returned"]=nr_ord["Returned"].apply(lambda x: "No" if x=="nan" else "Yes")
nr_ord.head(20)
# Out:
#                   Order ID  Market  Profit    Sales Returned
# 0     AG-2012-AA6453-41020  Africa   53.76   298.68       No
# 1     AG-2012-AC4203-40915  Africa   14.58    91.38       No
# 2     AG-2012-AH2103-41133  Africa   11.04   276.96       No
# 3     AG-2012-AJ7803-40978  Africa    7.17    35.97       No
# 4     AG-2012-AS2853-41235  Africa   15.36    54.90       No
# 5    AG-2012-BC11253-41219  Africa    4.14    10.92       No
# 6    AG-2012-BM17853-41052  Africa  148.68   874.68       No
# 7    AG-2012-BM17853-41085  Africa  177.18   510.24       No
# 8    AG-2012-CC23703-40970  Africa   29.43   113.28       No
# 9    AG-2012-DB32103-41257  Africa   20.52    58.74       No
# 10   AG-2012-DH36753-41136  Africa  222.48   607.26       No
# 11   AG-2012-DK28353-41264  Africa  349.56  1589.40       No
# 12   AG-2012-EG39003-41262  Africa   86.79  1475.97       No
# 13   AG-2012-JH59853-41214  Africa   10.86    24.72       No
# ...

# %%
import pandas as pd
df_1 = pd.read_csv('https://query.data.world/s/vv3snq28bp0TJq2ggCdxGOghEQKPZo')
df_2 = pd.read_csv('https://query.data.world/s/9wVKjNT0yiRc3YbVJaiI8a6HGl2d74')
df_3 = df_1.merge(df_2,on="unique_id")#Type your code here.
print(df_3.head(20))
# Out:
#                            name                     address              city  \
# 0     arnie morton's of chicago   "435 s. la cienega blvd."     "los angeles"
# 1                    art's deli       "12224 ventura blvd."     "studio city"
# 2                 bel-air hotel      "701 stone canyon rd."         "bel air"
# 3                    cafe bizou       "14016 ventura blvd."    "sherman oaks"
# 4                     campanile       "624 s. la brea ave."     "los angeles"
# 5               chinois on main             "2709 main st."    "santa monica"
# 6                        citrus         "6703 melrose ave."     "los angeles"
# 7           fenix at the argyle         "8358 sunset blvd."    "w. hollywood"
# 8                       granita       "23725 w. malibu rd."          "malibu"
# 9                    grill  the           "9560 dayton way"   "beverly hills"
# 10                        katsu       "1972 hillhurst ave."       "los feliz"
# ...

# %%
# Concatenating the dataframes across column: df1 and df3
import numpy as np 
import pandas as pd
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]})
gold.set_index("Country", inplace=True)
silver.set_index("Country", inplace=True)
bronze.set_index("Country", inplace=True)
total=gold.add(silver, axis=1, fill_value=0)
final=total.add(bronze,axis=1, fill_value=0)
final.sort_values(by="Medals", ascending=False)
# Out:
#          Medals
# Country
# USA        72.0
# France     53.0
# UK         27.0
# Russia     25.0
# Germany    20.0

# %%
import pandas as pd

df1 = pd.DataFrame({'Name': ['Aman', 'Joy', 'Rashmi', 'Saif'],
                    'Age' : ['34', '31', '22', '33'], 
                    'Gender': ['M', 'M', 'F', 'M']}
                  )

df2 = pd.DataFrame({'Name': ['Akhil', 'Asha', 'Preeti'],
                    'Age' : ['31', '22', '23'], 
                    'Gender': ['M', 'F', 'F']}
                  )
df4=pd.concat([df1,df2], axis=0)
df4
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
df3 = pd.DataFrame({'School': ['RK Public', 'JSP', 'Carmel Convent', 'St. Paul'],
                    'Graduation Marks': ['84', '89', '76', '91']})

df5=pd.concat([df1,df3],axis=1)
df5
# Out:
#      Name Age Gender          School Graduation Marks
# 0    Aman  34      M       RK Public               84
# 1     Joy  31      M             JSP               89
# 2  Rashmi  22      F  Carmel Convent               76
# 3    Saif  33      M        St. Paul               91

# %%
import pandas as pd
df=pd.read_csv("Movies.csv")
df.shape
# Out:
# (3853, 28)

# %%
count=0
df.apply(lambda x: count=count+1 if df[] )
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3848  Color      Shane Carruth                   143.0      77.0
# 3849  Color   Neill Dela Llana                    35.0      80.0
# 3850  Color   Robert Rodriguez                    56.0      81.0
# 3851  Color       Edward Burns                    14.0      95.0
# 3852  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...
